# %% [markdown]
# # EMINENCE: Combat Athlete Development — Generate API

# %%
import requests
import time
import json
from IPython.display import display, Markdown

RAW_OFFER = """EMINENCE: Combat Athlete Development

The problem:  
Traditional combat sports paths—train, fight, hope—rarely ensure financial stability. Generic advice like "post more" fails without a tailored strategy. Athletes often struggle because they lack the time and expertise to manage branding and marketing, while elusive sponsorships and missed opportunities in coaching, instructionals, and merchandise leave significant income untapped. We bridge this gap by providing the professional roadmap and infrastructure needed to monetize your combat career effectively.

The solution:  
Stardom coaching for MMA, muay thai, and BJJ fighters, which encompasses everything from personal branding to media appearances and social media growth, and the monetization around it.  
It's about applying the media/fame lever to martial arts money making. The goal is to increase popularity for all non-A players (aspiring amateurs, mid-level WSOF / cage warriors pros, low level UFC pros, etc) so that they can make more money in their fight contracts and more money through sponsorships, merch, youtube, coaching privates/seminars, instructionals, and all peripheral ventures.   
Emphasis on Monetization: Our primary goal is to increase your earning potential. We focus on tangible outcomes like higher fight contracts, securing sponsorships, and developing new revenue streams – not just vanity metrics.

3 service categories:

1) Stardom: find and define your personal brand.  
   1) Personal branding  
   2) Storytelling  
   3) Set your environment and behavior  
2) Visibility: create content and grow your audience.  
   1) Social media growth  
   2) Content production  
   3) Media appearances  
3) Monetization: make money from your fame.  
   1) Private classes  
   2) Seminars  
   3) Instructionals  
   4) Refereeing  
   5) Commentating/analyst  
   6) Merchandising  
   7) Sponsorships  
   8) Negotiating fight contracts

2 delivery methods, both recurring subscriptions of productized services:

1) DWY - needs a lot of the fighter's participation. We help them find their brand and set them on a new trajectory but the rest works with templates and recurring check-ins: they need to post themselves, do sponsor outreach themselves, media outreach themselves, negotiate contracts themselves, market their merch, instructionals, seminars themselves…  
2) DFY - still needs the fighter's participation for their performance and branding, but the rest is handled by us: sponsor outreach, posting to social media, editing content, deciding content formats and schedules, outreach for media appearances, seminar hype campaigns, instructionals marketing, merch marketing, fight contract negotiation…

2 avatars:

1) Aspiring fighter - Competition experience is not a strong lever. Any small increase in income is valued.  
   1) Amateur competitor  
   2) Low level pro competitor  
   3) Non-competitor who wants to make money through the sport  
2) Pro fighter - Competition experience is an underused lever. Increases in income must be time-worthwhile and should be in a compounding vehicle.  
   1) Mid level pro competitor - anyone who has real skills but their brand and finances don't reflect it.

2 very different price points:

1) Low price point. Low purchasing power. Needs to be made profitable by a small increase of income (hundreds per month)  
2) High price point. Medium purchasing power. Needs to be made profitable by long term compounding returns (thousands/mo after months, tens of thousands after years)

Guarantees:  
Needs guarantees that align our incentives with the user and make commitment free if it doesn't work.   
Maybe a general satisfaction guarantee after a month, and an open to goal guarantee around certain benchmarks after 6-12 months.
"""

data = None
for attempt in range(1, 6):
    print(f"Attempt {attempt}/5 …")
    r = requests.post(
        "https://web-production-ad536.up.railway.app/generate",
        json={"raw_offer": RAW_OFFER},
        timeout=120,
    )
    if r.status_code == 200:
        data = r.json()
        print(f"Success! Keys: {list(data.keys())}")
        break
    else:
        print(f"  Got {r.status_code}, retrying in 10 s …")
        time.sleep(10)

if data is None:
    raise RuntimeError("All attempts failed. Try running this cell again.")
# Out:
# Attempt 1/5 …
#   Got 500, retrying in 10 s …
# Attempt 2/5 …
# Success! Keys: ['sophisticated_offer', 'sales_page', 'vsl_script', 'call_script']

# %%
display(Markdown("---\n## 1. Sophisticated Offer\n\n" + data["sophisticated_offer"]))
# Out:
# ---
# ## 1. Sophisticated Offer
#
# Here is the comprehensive analysis and re-architecting of your "EMINENCE: Combat Athlete Development" offer.
#
# ## 1. Offer Diagnosis Report
#
# **Core Promise:** To provide combat athletes with a professional roadmap and infrastructure to effectively monetize their careers, increasing popularity and earning potential through strategic branding, visibility, and monetization ventures.
#
# **Mechanism:** Applying a media/fame lever to martial arts money-making by increasing popularity for non-elite athletes to unlock income from fight contracts, sponsorships, coaching, instructionals, merchandise, and other peripheral ventures.
#
# **Value Drivers:**
# *   Increased earning potential (fight contracts, sponsorships)
# *   Development of new revenue streams (coaching, seminars, merch, instructionals)
# *   Personal branding and storytelling expertise
# *   Content creation and social media growth
# *   Media appearance opportunities
# ...

# %%
display(Markdown("---\n## 2. Sales Page\n\n" + data["sales_page"]))
# Out:
# ---
# ## 2. Sales Page
#
# Here is your high-converting sales page copy, designed to transform combat athletes into thriving entrepreneurs.
#
# ---
#
# ## A. Headline + Subheadline Options
#
# **Option 1:**
# **Headline:** EMINENCE Pro: Turn Your Fight Career into a Fortune.
# **Subheadline:** Stop fighting for scraps. We handle your brand, content, and deal-making so you can command the income you deserve.
#
# **Option 2:**
# **Headline:** Stop Fighting for Money. Start Earning What You're Worth with EMINENCE Pro.
# **Subheadline:** Your ultimate partner in transforming combat sports talent into a lucrative, professionally managed enterprise.
#
# **Option 3:**
# **Headline:** The Athlete Enterprise Solution: Monetize Your Talent, Amplify Your Fame.
# **Subheadline:** Done-for-you branding, content, sponsorships, and contract negotiation to build your sustainable, high-earning career.
#
# **Option 4:**
# **Headline:** Your Personal Sponsorship & Contract Negotiators: EMINENCE Pro.
# ...

# %%
display(Markdown("---\n## 3. VSL Script\n\n" + data["vsl_script"]))
# Out:
# ---
# ## 3. VSL Script
#
# Okay, here is the VSL script generated from your Offer Architect output, following the proven structure and psychological principles.
#
# ***
#
# ## EMINENCE: Combat Athlete Development VSL Script
#
# **(Video Opens: Fast-paced montage of dynamic combat sports action – striking, grappling, intense training. Upbeat, motivating music starts then fades slightly as VO begins.)**
#
# **VOICEOVER (Energetic, Confident):** You’re an athlete. You live for the fight, the grind, the moment of victory. But what about the rest of your career? Are you truly earning what your talent, dedication, and sacrifices are worth?
#
# ### 1. Pattern Interrupt Hook
#
# **(Visual: Transition to a slightly slower, more direct shot of the speaker, looking straight at the camera. Music becomes more subdued but still driving.)**
#
# ...

# %%
display(Markdown("---\n## 4. Call Script\n\n" + data["call_script"]))
# Out:
# ---
# ## 4. Call Script
#
# Here is your comprehensive sales call script, designed to convert combat athletes by leveraging the EMINENCE offer architecture.
#
# ***
#
# ## EMINENCE Pro: Sales Call Script
#
# **Goal:** To convert qualified combat athletes into EMINENCE Pro clients by demonstrating clear value, addressing their core pain points, and showcasing how our Done-For-You system unlocks their earning potential.
#
# **Tone:** Warm, confident, empathetic, authoritative, consultative, not pushy.
#
# ---
#
# ### **1. Open / Frame (Approx. 3 minutes)**
#
# **(Rep Introduction)**
# "Hey [Athlete Name], this is [Your Name] from EMINENCE. How are you doing today?"
#
# **(Acknowledge their time)**
# "Thanks so much for taking the time to chat with me. I know your schedule is incredibly demanding, so I appreciate you carving out this space."
#
# **(Set the Tone & Establish Leadership)**
# ...
